# %% [markdown]
# <a href="https://colab.research.google.com/github/dymiyata/python-pro-intro-to-ml-spring-2026/blob/main/train_test_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Test Split and Model Evaluation Homework

# %% [markdown]
# Create your own copy of this notebook.  Then, upload your completed assignment to the corresponding assinment on the class page.
#
# As always, add as many code cells/text cells as needed to properly present your work.

# %% [markdown]
# Run the following cell to import the necessary libraries and modules.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Next, load some data that I synthetically created for this assingment by running the following cell.  **Do not edit the following cell in any way**

# %%
# Set the random seed so that everyone has the same values
rng = np.random.default_rng(seed=2025)

# Set size of the data set
m = 100

# Define the x values for the data set
x = np.linspace(-15, 10, m)[:, np.newaxis]

# Define y using some data I created
y = np.array([[-0.1350155 ], [11.62205645], [11.98646947], [12.10899065], [ 9.20373843],[24.24313954], [20.22092971], [26.27666788], [29.83834394], [29.89876325],[29.51638172], [34.40463238], [35.19538611], [36.74572552], [28.86849245], [34.92410147], [34.70045458], [49.96933238], [36.28495466], [44.59699751], [33.37479957], [38.9443224 ], [35.16925875], [41.94666537], [48.62301434], [37.92031237], [44.68874785], [44.60033731], [43.96743938], [40.33930124], [40.39956809], [41.27892397], [41.22338062], [40.62644578], [42.67010675], [38.55441297], [40.70762822], [39.1567264 ], [32.83133389], [32.99797618], [38.23914273], [37.18553146], [38.827805  ], [24.78369551], [35.38185782], [22.46126753], [31.05443239], [20.51138023], [34.97124353], [25.27958117], [36.54518839], [27.81801329], [29.48182826], [27.53825279], [31.57708092], [23.4205411 ], [18.13734348], [17.14143675], [17.4155809 ], [20.51564024], [20.95268929], [17.78472717], [18.74594799], [23.67243336], [ 9.75674278], [14.03671483], [19.79948135], [10.926909  ], [18.88644434], [12.63087513], [11.6383709 ], [12.90809069], [14.1368642 ], [11.90595344], [19.24084951], [11.67801598], [17.93573836], [17.64998212], [12.62490909], [19.27704075], [21.41831034], [17.0925974 ], [18.53083519], [ 8.64213748], [18.71158594], [21.59774507], [25.41090804], [17.28320596], [21.03755189], [26.21346365], [19.95613967], [26.70729916], [14.00429461], [29.78544174], [22.62958869], [24.41386721], [31.79282254], [33.24723078], [37.54214804], [29.89171417]])

# %% [markdown]
# ## Problem 1
#
# Create a scatter plot of `x` vs `y` to visualize the data.
# - Note, `x` and `y` were defined as 2D arrays which are each a single column.
# - `sns.scatterplot` expects 1D arrays as input so you'll have to extract the first column of each of these as a 1D array to use as arguments in the `sns.scatterplot` function.

# %% [markdown]
# ## Problem 2
#
# Use the `train_test_split` function to separate the data into a training set and a testing set.  Use 80\% of the data for training and 20\% for testing.

# %% [markdown]
# ## Problem 3
#
# In later problems, we will make four different polynomial regression models.
#
# In preparation for that, in this problem, we will have four different sets of polynomial features.
# - The first should use the features $x$ and $x^2$ (to give a quadratic model)
# - The second should use the features $x$, $x^2$, $x^3$.
# - The third should use as features, all powers of $x$ up to $x^7$.
# - The last should use as features, all powers of $x$ up to $x^{15}$.
#
# Create a training matrix and a testing matrix for each of these choices of features.
# - When you define these feature matrices, just like we did in class, _normalize_ the features by scalling $x^n$ by $0.1^{n-1}$.
#   - Recall, this is help make the larger powers of $x$ not blow up which helps the learning algorithm more accurately find the weights.
# - There are more proper ways to do normalization of the features, but for now we will use this crude method.

# %% [markdown]
# ## Problem 4
#
# Define and train four different `LinearRegression()` models, one for each of the feature matrices you defined above.  Be sure to name them different things so you can differentiate them.

# %% [markdown]
# ## Problem 5
#
# For each model, create $y$ prediction arrays.
# - You need a testing and a training prediction array for each model

# %% [markdown]
# ## Problem 6
#
# For each model, use your prediction arrays to compute the Mean Squared Error (MSE) for both the training set and the testing set.
#
# Then, using these results, which models seem to be underfitting which seem to be over fitting?
#
# Finally, conclude which of the four models is the best.
